# %%
import pandas as pd
#Importar biblioteca/Pandas

tabela1 = pd.read_excel("RelAlunosAptos_1982022951.xlsx")
tabela2 = pd.read_excel("RelAlunosAptos_18820221552.xlsx")
#Ler tabelas do excel

tabela = pd.concat([tabela1, tabela2])
#Concatenar tabelas

display(tabela)
#Visualizar Tabela concatenada

tabela.to_excel("final_output1.xlsx", index=False)
#Importa nova planilha para excel
# Out:
#      Código DRE                                                DRE  \
# 0        109000  DIR EDUC - DIRETORIA REGIONAL DE EDUCACAO PIRI...
# 1        109000  DIR EDUC - DIRETORIA REGIONAL DE EDUCACAO PIRI...
# 2        109000  DIR EDUC - DIRETORIA REGIONAL DE EDUCACAO PIRI...
# 3        109000  DIR EDUC - DIRETORIA REGIONAL DE EDUCACAO PIRI...
# 4        109000  DIR EDUC - DIRETORIA REGIONAL DE EDUCACAO PIRI...
# ..          ...                                                ...
# 378      109000  DIR EDUC - DIRETORIA REGIONAL DE EDUCACAO PIRI...
# 379      109000  DIR EDUC - DIRETORIA REGIONAL DE EDUCACAO PIRI...
# 380      109000  DIR EDUC - DIRETORIA REGIONAL DE EDUCACAO PIRI...
# 381      109000  DIR EDUC - DIRETORIA REGIONAL DE EDUCACAO PIRI...
# 382      109000  DIR EDUC - DIRETORIA REGIONAL DE EDUCACAO PIRI...
#
#      Código Escola                        Nome Escola  Código EOL  \
# 0            93106  EMEF - DILERMANDO DIAS DOS SANTOS     6189837
# ...
